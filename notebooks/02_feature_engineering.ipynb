# %% [markdown]
# ### **Library Imports**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### **Data Imports**

# %%
# experimental so we can just import the train data

train = pd.read_csv('../data/03_primary/X_train_cleaned_validated.csv')
train.head()
# Out:
#    patient_nbr  race  gender  age  admission_type_id  \
# 0     99553419     0       1   85                  1
# 1      1156392     0       1   65                  1
# 2    109279710     0       1   85                  3
# 3     41843502     0       1   65                  1
# 4     18003051     0       1   65                  1
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 0                         1                    7                10
# 1                         1                    7                 4
# 2                         1                    1                 1
# 3                         6                    7                 8
# 4                         6                    7                12
#
#    num_lab_procedures  num_procedures  ...  troglitazone  tolazamide  insulin  \
# 0                  45               0  ...             0           0        0
# 1                  39               0  ...             0           0        0
# ...

# %%
train.describe().T
# Out:
#                             count          mean           std    min  \
# patient_nbr               68623.0  5.481621e+07  3.872073e+07  135.0
# race                      68623.0  3.258820e-01  7.338887e-01    0.0
# gender                    68623.0  5.383181e-01  4.985332e-01    0.0
# age                       68623.0  6.624798e+01  1.560993e+01    5.0
# admission_type_id         68623.0  2.017079e+00  1.441474e+00    1.0
# discharge_disposition_id  68623.0  3.752736e+00  5.315266e+00    1.0
# admission_source_id       68623.0  5.775265e+00  4.063761e+00    1.0
# time_in_hospital          68623.0  4.426533e+00  2.998099e+00    1.0
# num_lab_procedures        68623.0  4.314829e+01  1.979028e+01    1.0
# num_procedures            68623.0  1.345744e+00  1.705474e+00    0.0
# num_medications           68623.0  1.609937e+01  8.099885e+00    1.0
# number_outpatient         68623.0  3.756175e-01  1.286211e+00    0.0
# number_emergency          68623.0  2.011570e-01  8.990718e-01    0.0
# ...

# %% [markdown]
# ### **Feature Engineering**

# %%
# total visits in previous year

def total_visits_in_previous_year(X: pd.DataFrame) -> pd.DataFrame:
    X['total_visits_in_previous_year'] = X['number_outpatient']\
                                        + X['number_emergency']\
                                        + X['number_inpatient']
    return X


train = total_visits_in_previous_year(train)

# %%
# comorbidity index

# %%
# discharge disposition
# e.g. if expired then always predict 0
